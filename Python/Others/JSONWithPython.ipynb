# %%
import numpy as np
from pandas import Series, DataFrame
import pandas as pd
import json

# %%
with open('/Users/biswajitkarmokar/Downloads/airfields.json') as data_file:    
    data = json.load(data_file)
#data

# %%
# WE can also convert back to JSON
# json.dumps(data)

# %%
#We can simply open JSON data after loading with a DataFrame
dframe = DataFrame(data)
dframe
# Out:
#       Catalog  Elevation  Flags  Frequency  ICAO     ID Latitude  Length  \
# 0           0         67     72       0.00  LFOI   LFOI  N500835    1260
# 1           0         61     32     121.30  LFBA   LFBA  N441029    2170
# 2           0         30   1028       0.00        AIGRE  N460738       0
# 3           0        199   1028       0.00        AINYL  N464024       0
# 4           0         35   1028       0.00        AIREL  N503713       0
# 5           0         80     32     118.97  LFDA   LFDA  N434229       0
# 6           0        160   1027     123.50         AIRS  N435427       0
# 7          60        300    258       0.00        AITON  N453325       0
# 8           0        531   1024     130.00        AIXEN  N444121       0
# 9           0        105     32     118.75  LFMA   LFMA  N433019    1590
# 10          0          6     32     118.07  LFKJ   LFKJ  N415526    2390
# 11          0        110     40     119.65  LFAQ   LFAQ  N495812    2210
# ...

# %%
with open('/Users/biswajitkarmokar/Downloads/consumer.json') as data_file:    
    consumerdata = json.load(data_file)

# %%
dframe_cons = DataFrame(consumerdata)
dframe_cons["tableAuthor"][0]["rights"]
# Out:
# [u'create_datasets',
#  u'edit_others_datasets',
#  u'edit_nominations',
#  u'approve_nominations',
#  u'moderate_comments',
#  u'manage_stories',
#  u'feature_items',
#  u'change_configurations',
#  u'view_domain',
#  u'view_others_datasets',
#  u'create_pages',
#  u'edit_pages',
#  u'view_goals',
#  u'view_dashboards',
#  u'edit_goals',
#  u'edit_dashboards',
#  u'manage_provenance',
#  u'view_story',
#  u'view_unpublished_story',
#  u'view_all_dataset_status_logs']
